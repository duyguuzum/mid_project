# %% [markdown]
# We have two questions to calculate the answers using a Machine Learning Model.
#
# Q1- Which company_location has the lowest salary?
#
# Q2- Which job_title that has the highest salary

# %% [markdown]
# We will use the Scikit-Learn library and the workflow as follows, to get a model with a good performance.

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('../data/raw/ds_salaries.csv',index_col=0)
data
# Out:
#             work_year experience_level employment_type  \
# Unnamed: 0
# 0                2020               MI              FT
# 1                2020               SE              FT
# 2                2020               SE              FT
# 3                2020               MI              FT
# 4                2020               SE              FT
# ...               ...              ...             ...
# 602              2022               SE              FT
# 603              2022               SE              FT
# 604              2022               SE              FT
# 605              2022               SE              FT
# 606              2022               MI              FT
#
#                              job_title  salary salary_currency  salary_in_usd  \
# Unnamed: 0
# 0                       Data Scientist   70000             EUR          79833
# 1           Machine Learning Scientist  260000             USD         260000
# ...

# %% [markdown]
# # Data description

# %% [markdown]
# The following table gives an explanation of each column of our dataset.

# %% [markdown]
# | Column name | Description |
# | --- | --- |
# | work_year | instant year |
# | experience_level | experience of the employee |
# | employment_type | working hours |
# | job_title | Job description |
# | salary | the salary of the local currency |
# | salary_currency | local currency |
# | salary_in_usd | salary in USD |
# | employee_residence | location of the employee |
# | remote_ratio | the ration of remote working|
# | company_location | location of the company |
# | company_size |  size of the company |

# %% [markdown]
# We will do the data cleaning steps in the cleaning_data notebook.

# %% [markdown]
# # Data Analysis Techniques

# %% [markdown]
# We will use the model RandomForestRegressor to find answers to our questions. Because we have categorical columns in our database. It makes issues when we use the Linear Regression model. Best performance for the answers we get from the RandomForestRegressor.
